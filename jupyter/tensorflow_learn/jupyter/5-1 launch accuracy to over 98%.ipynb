# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import  input_data

# %%
#dataset
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

# 
batch_size = 100
#
n_batch = mnist.train.num_examples   //batch_size

x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)
lr = tf.Variable(0.001, dtype=tf.float32)

#creat a network
W1 = tf.Variable(tf.truncated_normal([784,500], stddev=0.1))
b1 = tf.Variable(tf.zeros([500])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([500,300], stddev=0.1))
b2 = tf.Variable(tf.zeros([300])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2, keep_prob)

W4 = tf.Variable(tf.truncated_normal([300,10], stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.softmax(tf.matmul(L2_drop,W4)+b4)

# a simple network
# W = tf.Variable(tf.zeros([784,10]))
# b = tf.Variable(tf.zeros([10]))
# prediction = tf.nn.softmax(tf.matmul(x,W)+b)

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=prediction))

train_step = tf.train.AdamOptimizer(lr).minimize(loss)

init = tf.global_variables_initializer()

correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction,1))

accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(51):
#         sess.run(tf.assign(lr, 0.001 * (0.95 ** epoch)))
        sess.run(tf.assign(lr, lr * (0.9 )))
        for batch in range (n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys, keep_prob:1.0}) #
            
        learning_rate = sess.run(lr)
        test_acc = sess.run(accuracy, feed_dict={x:mnist.test.images, y:mnist.test.labels, keep_prob:1.0})
#         train_acc = sess.run(accuracy, feed_dict={x:mnist.train.images, y:mnist.train.labels, keep_prob:1.0})
        print("Iter "+ str(epoch) + ", Testing Accuracy "+ str(test_acc) + ", Learning Rate "+ str(learning_rate))#
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0, Testing Accuracy 0.9459, Learning Rate 0.0009
# Iter 1, Testing Accuracy 0.9632, Learning Rate 0.00081
# Iter 2, Testing Accuracy 0.9689, Learning Rate 0.000729
# Iter 3, Testing Accuracy 0.9724, Learning Rate 0.0006561
# Iter 4, Testing Accuracy 0.9738, Learning Rate 0.00059049
# Iter 5, Testing Accuracy 0.9721, Learning Rate 0.000531441
# Iter 6, Testing Accuracy 0.9768, Learning Rate 0.000478297
# Iter 7, Testing Accuracy 0.9784, Learning Rate 0.000430467
# Iter 8, Testing Accuracy 0.9776, Learning Rate 0.00038742
# Iter 9, Testing Accuracy 0.9794, Learning Rate 0.000348678
# Iter 10, Testing Accuracy 0.98, Learning Rate 0.000313811
# Iter 11, Testing Accuracy 0.9802, Learning Rate 0.000282429
# Iter 12, Testing Accuracy 0.98, Learning Rate 0.000254187
# ...

# %%
Iter 0, Testing Accuracy 0.9467, Learning Rate 0.001
Iter 1, Testing Accuracy 0.9634, Learning Rate 0.00095
Iter 2, Testing Accuracy 0.9656, Learning Rate 0.0009025
Iter 3, Testing Accuracy 0.9715, Learning Rate 0.000857375
Iter 4, Testing Accuracy 0.9733, Learning Rate 0.000814506
Iter 5, Testing Accuracy 0.9746, Learning Rate 0.000773781
Iter 6, Testing Accuracy 0.9755, Learning Rate 0.000735092
Iter 7, Testing Accuracy 0.9772, Learning Rate 0.000698337
Iter 8, Testing Accuracy 0.9778, Learning Rate 0.00066342
Iter 9, Testing Accuracy 0.9756, Learning Rate 0.000630249
Iter 10, Testing Accuracy 0.9792, Learning Rate 0.000598737
Iter 11, Testing Accuracy 0.9783, Learning Rate 0.0005688
Iter 12, Testing Accuracy 0.9783, Learning Rate 0.00054036
Iter 13, Testing Accuracy 0.9795, Learning Rate 0.000513342
Iter 14, Testing Accuracy 0.9785, Learning Rate 0.000487675
Iter 15, Testing Accuracy 0.9788, Learning Rate 0.000463291
Iter 16, Testing Accuracy 0.979, Learning Rate 0.000440127
Iter 17, Testing Accuracy 0.9798, Learning Rate 0.00041812
Iter 18, Testing Accuracy 0.9796, Learning Rate 0.000397214
Iter 19, Testing Accuracy 0.9767, Learning Rate 0.000377354
Iter 20, Testing Accuracy 0.9813, Learning Rate 0.000358486
Iter 21, Testing Accuracy 0.981, Learning Rate 0.000340562
Iter 22, Testing Accuracy 0.9799, Learning Rate 0.000323534
Iter 23, Testing Accuracy 0.9806, Learning Rate 0.000307357
Iter 24, Testing Accuracy 0.9815, Learning Rate 0.000291989
Iter 25, Testing Accuracy 0.9807, Learning Rate 0.00027739
Iter 26, Testing Accuracy 0.9809, Learning Rate 0.00026352
Iter 27, Testing Accuracy 0.9813, Learning Rate 0.000250344
Iter 28, Testing Accuracy 0.982, Learning Rate 0.000237827
Iter 29, Testing Accuracy 0.9814, Learning Rate 0.000225936
Iter 30, Testing Accuracy 0.9809, Learning Rate 0.000214639
Iter 31, Testing Accuracy 0.9816, Learning Rate 0.000203907
Iter 32, Testing Accuracy 0.9818, Learning Rate 0.000193711
Iter 33, Testing Accuracy 0.9812, Learning Rate 0.000184026
Iter 34, Testing Accuracy 0.9818, Learning Rate 0.000174825
Iter 35, Testing Accuracy 0.9823, Learning Rate 0.000166083
Iter 36, Testing Accuracy 0.9824, Learning Rate 0.000157779
Iter 37, Testing Accuracy 0.9809, Learning Rate 0.00014989
Iter 38, Testing Accuracy 0.9826, Learning Rate 0.000142396
Iter 39, Testing Accuracy 0.9824, Learning Rate 0.000135276
Iter 40, Testing Accuracy 0.9814, Learning Rate 0.000128512
Iter 41, Testing Accuracy 0.9821, Learning Rate 0.000122087
Iter 42, Testing Accuracy 0.9825, Learning Rate 0.000115982
Iter 43, Testing Accuracy 0.9827, Learning Rate 0.000110183
Iter 44, Testing Accuracy 0.9825, Learning Rate 0.000104674
Iter 45, Testing Accuracy 0.9831, Learning Rate 9.94403e-05
Iter 46, Testing Accuracy 0.9826, Learning Rate 9.44682e-05
Iter 47, Testing Accuracy 0.9832, Learning Rate 8.97448e-05
Iter 48, Testing Accuracy 0.9829, Learning Rate 8.52576e-05
Iter 49, Testing Accuracy 0.9836, Learning Rate 8.09947e-05
Iter 50, Testing Accuracy 0.9829, Learning Rate 7.6945e-05
